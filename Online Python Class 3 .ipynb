# %%
# Comment how to add Comments

# %%
arr = [ 112 , 9]
print (arr)
# Out:
# [112, 9]

# %%
"""We are learning python 
learning list now"""

print ("Hello World")
# Out:
# Hello World

# %%
name1 = "zul";
name2 = "Rani";
name3 = "Shanzi";
name4 = "Manjki";
name5 = "jigi";  

print ( name1+ ","+name2+ "," +name3+ "," +name4+ "," +name5+ "," )
# Out:
# zul,Rani,Shanzi,Manjki,jigi,

# %%
1 # list 
2
name = ["Zulqi","Rani","Ehsan", "Smaina","Bilal","Annad"];
print (name);
# Out:
# ['Zulqi', 'Rani', 'Ehsan', 'Smaina', 'Bilal', 'Annad']

# %%
print (name[0]);
# Out:
# Zulqi

# %%
name [1]= "ALi";
print (name);
# Out:
# ['Zulqi', 'ALi', 'Ehsan', 'Smaina', 'Bilal', 'Annad']

# %%
name.append("Ahmed");
print (name);
# Out:
# ['Zulqi', 'ALi', 'Ehsan', 'Smaina', 'Bilal', 'Annad', 'Ahmed']

# %%
arr = ["lion", 11, True,5.65];
print (arr);
# Out:
# ['lion', 11, True, 5.65]

# %%
name
# Out:
# ['Zulqi', 'ALi', 'Ehsan', 'Smaina', 'Bilal', 'Annad', 'Ahmed']

# %%
newList = name + arr;
print (newList);
# Out:
# ['Zulqi', 'ALi', 'Ehsan', 'Smaina', 'Bilal', 'Annad', 'Ahmed', 'lion', 11, True, 5.65]

# %%
name = name .insert(3,"RAshid")
print(name)
# Out:
# None

# %%
arr2 = arr[2:4];
print(arr2);
# Out:
# [True, 5.65]

# %%
arr4 = arr[:3]
print (arr4)
# Out:
# ['lion', 11, True]

# %%
del arr [2]
print(arr);
# Out:
# ['lion', 11, 5.65]

# %%
arr.remove(11)
print(arr);
# Out:
# ['lion', 5.65]

# %%
arr.pop()
print(arr);
# Out:
# ['lion']
