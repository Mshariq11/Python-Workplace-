# %%
c = "HELLO SHARIQ";
print (c)
# Out:
# HELLO SHARIQ

# %%
c ="SHARIQ";
print ("MY NAME IS " +c);
# Out:
# MY NAME IS SHARIQ

# %%
a = 5;
b = 10;
c = a + b;
print (c)
# Out:
# 15

# %%
x = "SHAW";
y = "RICK";
z = x + y;
print (z);
# Out:
# SHAWRICK

# %%
f = "4";
g = "8";
h = f + g;
print (h);
# Out:
# 48

# %%
a = "10";
b = 20;
c = a + b;
print (c);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-f6298759cf0a> in <module>
#       1 a = "10";
#       2 b = 20;
# ----> 3 c = a+ b;
#       4 print (c);
#
# TypeError: can only concatenate str (not "int") to str

# %%
x = 8;
y = x + 7;
z = y - x + 1; 
print (z);
# Out:
# 8

# %%
a = 12 - 4 / 2 + 9 * 5;
print (a);
# Out:
# 55.0

# %%
a = ( (12 - 4)  / (2 + 9) * 5);
print (a);
# Out:
# 3.6363636363636367

# %%
x = 10;
y = x%3;
print (y);
# Out:
# 1

# %%
f = 10;
f = 12;
print (f);
# Out:
# 12

# %%
g = 5 
g = g + 2;
print (g);
# Out:
# 7

# %%
a = 3;
a+=3;
print (a);
# Out:
# 6

# %%
gender = "male";
if gender == "male":
    print ("Allow for Ride");
# Out:
# Allow for Ride

# %%
gender = "female";
if gender == "male":
    print ("Allow for Ride");
else:
    print ("ROK LO");
# Out:
# ROK LO

# %%
age = 14;
gender = "female";
if age > 18 or gender == "male":
    print ("Allow for Ride");
else:
    print ("ROK LO");
# Out:
# ROK LO

# %%
percent = 82;
if percent < 100 and percent > 80 :
    print ("Grade A+")
elif  percent < 80 and percent > 70 :
        print ("Grade A"); 
else :
    print ("Fail")
# Out:
# Grade A+

# %% [markdown]
# # x = "Marksheet";
# percent = 85;
# if percent < 95 and percent > 80 :
#     print ("Grade A+")
# elif percent < 79 and percent > 70 :
#     print ("Grade A")
# elif percent < 69 and percent > 60 :
#     print ("Grade B")
# elif percent < 59 and percent > 50 :
#     print ("Grade C")
# else :
#     Print ("Fail")

# %%
x = "Marksheet";
percent = 65;
if percent < 100 and percent > 90 :
    Print ("Grade A+")
elif percent < 90 and percent > 80 :
    print ("Grade A-")
elif percent < 80 and percent > 70 :
    print ("Grade A")
elif percent < 70 and percent > 60 :
    print ("Grade B")
elif percent < 60 and percent > 50 :
    print ("Grade C")
elif percent < 50 and percent > 40 :
    print ("Grade D")
else :
    print ("Fail")
# Out:
# Grade B

# %%
eng = 55;
isl = 85;
maths = 95; 
total = 300; 
percent = (eng + isl + maths )/total*100;
if percent < 100 and percent >= 80 :
    print ("A+");
elif percent < 80 and percent >= 70 :
    print ("A"); 
elif percent < 70 and percent >= 60 :
        print ("C"); 
elif percent < 60 and percent >= 50 : 
        print ("D"); 
elif percent < 50 and percent >= 40 : 
        print ("E"); 
elif percent < 40 and percent >= 33 : 
        print ("F");
elif percent < 0 and percent > 100 : 
        print (" You didnot write correct percent");
else :
    Print ("Fail");
# Out:
# A

# %%
eng =  int (input ( "EnterEnglish Marks"));
isl =  int (input ( "Enter Islamiat Marks"));
maths = int ( input ( "Enter Maths Marks")); 
total = 300; 
percent = (eng + isl + maths)/total*100;
if percent < 100 and percent >= 80:
    print ("A+");
elif percent < 80 and percent >= 70: 
    Print ("A"); 
elif percent < 70 and percent >= 60: 
    Print ("B"); 
elif percent < 60 and percent >= 50: 
    Print ("C"); 
elif percent < 50 and percent >= 40: 
    Print ("D"); 
elif percent < 40 and percent >= 33: 
    Print ("E");
elif percent < 0 and percent > 100: 
    print (" You didnot write correct percent");
else :
    Print ("Fail");
# Out:
# EnterEnglish Marks95
# Enter Islamiat Marks85
# Enter Maths Marks85
# A+

# %%
x = int (input ("Enter a value") );
y = 25 
z = x + y;
print (z);
# Out:
# Enter a value35
# 60

# %%
x = int (input ("Enter a value") );
y = 25 
z =int (x) + y;
print (z);
# Out:
# Enter a value45
# 70

# %% [markdown]
# # **Sign is power

# %%
x = 3**2
print (x);
# Out:
# 9

# %%
# /n for spacing

# %%
print ("Hello\nWorld")
# Out:
# Hello
# World

# %%
x = 10;
y = 12;
a = 30;
b = 8;
if x+y == a-b:
    print (True);
else:
    print (False);
# Out:
# True

# %%
age = input ("Enter age");
gender = input ("Enter gender");
if age > 18 and gender == "male":
    print ("Allow");
else :
    print ("Donot Allow");
# Out:
# Enter age20
# Enter gendermale
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-e0a3a4d8b7ad> in <module>
#       1 age = input ("Enter age");
#       2 gender = input ("Enter gender");
# ----> 3 if age > 18 and gender == "male":
#       4     print ("Allow");
#       5 else :
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
age = input ("Enter age");
gender = input ("Enter gender");
if age > 18 and gender == "male":
    print ("Allow");
else :
    print ("Donot Allow");
# Out:
# Enter age18
# Enter gendermale
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-e0a3a4d8b7ad> in <module>
#       1 age = input ("Enter age");
#       2 gender = input ("Enter gender");
# ----> 3 if age > 18 and gender == "male":
#       4     print ("Allow");
#       5 else :
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
age = input ("Enter age");
gender = input ("Enter gender");
if age > 18 or gender == "male":
    print ("Allow");
else :
    print ("Donot Allow");
# Out:
# Enter age15
# Enter gendermale
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-5200ec9ed8cf> in <module>
#       1 age = input ("Enter age");
#       2 gender = input ("Enter gender");
# ----> 3 if age > 18 or gender == "male":
#       4     print ("Allow");
#       5 else :
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
# Out:
# [112, 9]

# %%
# Out:
# Hello World

# %%
# Out:
# zul,Rani,Shanzi,Manjki,jigi,

# %%
# Out:
# ['Zulqi', 'Rani', 'Ehsan', 'Smaina', 'Bilal', 'Annad']

# %%
# Out:
# Zulqi

# %%
# Out:
# ['Zulqi', 'ALi', 'Ehsan', 'Smaina', 'Bilal', 'Annad']

# %%
# Out:
# ['Zulqi', 'ALi', 'Ehsan', 'Smaina', 'Bilal', 'Annad', 'Ahmed']

# %%
# Out:
# ['lion', 11, True, 5.65]

# %%
# Out:
# ['Zulqi', 'ALi', 'Ehsan', 'Smaina', 'Bilal', 'Annad', 'Ahmed']

# %%
# Out:
# ['Zulqi', 'ALi', 'Ehsan', 'Smaina', 'Bilal', 'Annad', 'Ahmed', 'lion', 11, True, 5.65]

# %%
# Out:
# None

# %%
# Out:
# [True, 5.65]

# %%
# Out:
# ['lion', 11, True]

# %%
# Out:
# ['lion', 11, 5.65]

# %%
# Out:
# ['lion', 5.65]

# %%
# Out:
# ['lion']
